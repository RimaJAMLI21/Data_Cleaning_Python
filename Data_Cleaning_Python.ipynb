# %% [markdown]
# # Data Cleaning

# %%
# EDA Packages

import pandas as pd
import numpy as np

# %% [raw]
# Loading or Reading the file:
#
# -Encoding Error
# -Inconsstent Rows

# %%
#Issue 1
df = pd.read_csv("D:\Cleaning\Data\unclean_data.csv")
# Out:
#   Input In [2]
#     df = pd.read_csv("D:\Cleaning\Data\unclean_data.csv")
#                                                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 16-17: truncated \uXXXX escape

# %%
# Solution 1
#UTF Encoding
df = pd.read_csv(r"D:\Cleaning\Data\unclean_data.csv",encoding='latin1')
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
# Solution 2
#use text Editor and save it as UTF-8,ISO-8859-1,Latin
df1 = pd.read_csv(r"D:\Cleaning\Data\unclean_data.csv",encoding='latin1')
df1.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [raw]
# Inconsistent COlumn Names:
#
# -Change Cases
# -Rename them

# %%
df1.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
#Change the case to Upper
df1.columns = df1.columns.str.upper()
df1.columns
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %%
#Change the case  to proper case
df1 = df1.rename(columns=lambda x: x.title())
df1.columns
# Out:
# Index(['Movie_Title', 'Num_Critic_For_Reviews', 'Duration',
#        'Director_Facebook_Likes', 'Actor_3_Facebook_Likes',
#        'Actor_1_Facebook_Likes', 'Gross', 'Num_Voted_Users',
#        'Cast_Total_Facebook_Likes', 'Facenumber_In_Poster',
#        'Num_User_For_Reviews', 'Budget', 'Title_Year',
#        'Actor_2_Facebook_Likes', 'Imdb_Score', 'Title_Year.1'],
#       dtype='object')

# %%
#Renaming Columns
df1.rename(columns= {'Duration':'Time'})
# Out:
#                                      Movie_Title  Num_Critic_For_Reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [raw]
# Missing data:
#
# -Add a default value for missing data or use mean to fill it
# -Delete the row/column with missing data
# -Interpolate the rows
# -Replace
#
# To check the missing data
# False means no missing data
#
#         *df.isnull().sum()int
#         *df.isnull().any()bool

# %%
df1.isnull()
# Out:
#     Movie_Title  Num_Critic_For_Reviews  Duration  Director_Facebook_Likes  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                   False     False                    False
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
#Columns with NAN using True/False
#False means it doesn't have a NAN
df1.isnull().any()
# Out:
# Movie_Title                  False
# Num_Critic_For_Reviews       False
# Duration                      True
# Director_Facebook_Likes       True
# Actor_3_Facebook_Likes       False
# Actor_1_Facebook_Likes       False
# Gross                        False
# Num_Voted_Users               True
# Cast_Total_Facebook_Likes     True
# Facenumber_In_Poster          True
# Num_User_For_Reviews         False
# Budget                       False
# Title_Year                   False
# Actor_2_Facebook_Likes        True
# Imdb_Score                   False
# Title_Year.1                  True
# dtype: bool

# %%
#for entire DtaFrame
df.isnull().any().any()
# Out:
# True

# %%
#Columns with NAN using integer
df1.isnull().sum()
# Out:
# Movie_Title                  0
# Num_Critic_For_Reviews       0
# Duration                     3
# Director_Facebook_Likes      2
# Actor_3_Facebook_Likes       0
# Actor_1_Facebook_Likes       0
# Gross                        0
# Num_Voted_Users              1
# Cast_Total_Facebook_Likes    2
# Facenumber_In_Poster         5
# Num_User_For_Reviews         0
# Budget                       0
# Title_Year                   0
# Actor_2_Facebook_Likes       1
# Imdb_Score                   0
# Title_Year.1                 7
# dtype: int64

# %%
#Total Number of missing NA
df.isnull().sum().sum()
# Out:
# 21

# %% [raw]
# Adding A Default Value or Filling The Missing Data

# %%
df1.head()
# Out:
#                                   Movie_Title  Num_Critic_For_Reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    Duration Director_Facebook_Likes  Actor_3_Facebook_Likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    Actor_1_Facebook_Likes      Gross  Num_Voted_Users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df1_with_0 = df1.fillna(0)
df1_with_0.head()
# Out:
#                                   Movie_Title  Num_Critic_For_Reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    Duration Director_Facebook_Likes  Actor_3_Facebook_Likes  \
# 0     178.0                      10                     855
# 1       0.0                     563                    1000
# 2     148.0                      20                     161
# 3       0.0                   22000                   23000
# 4     132.0                   "475"                     530
#
#    Actor_1_Facebook_Likes      Gross  Num_Voted_Users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df1_with_0.isnull().sum().sum()
# Out:
# 0

# %%
#Fill it with the mean 
df1['Duration'].mean()
# Out:
# 150.72727272727272

# %%
df1_with_mean = df1.fillna(df1['Duration'].mean())

# %%
df1_with_mean
# Out:
#                                      Movie_Title  Num_Critic_For_Reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df.isnull().sum().sum()
# Out:
# 21

# %%
#The shape returns the number of rows and columns in the DataFrame
df.shape
# Out:
# (14, 16)

# %%
df_drop = df.dropna()

# %%
df_drop.shape
# Out:
# (4, 16)

# %%
df_drop
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 2                                      Spectre?ÿ                     602
# 8                      Avengers: Age of Ultron?ÿ                     635
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 2      148.0                      20                     161
# 8      141.0                      10                   19000
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 2                    11000  200074175         275868.0
# 8                    26000  458991599         462669.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
# ...

# %%
df_with_condition = df.dropna(how='any',thresh=1)

# %%
# ?df.dropna

# %%
df_with_condition.shape
# Out:
# (14, 16)

# %%
df.shape
# Out:
# (14, 16)

# %%
df_drop_column = df.dropna(axis=1)

# %%
df_drop_column.shape
# Out:
# (14, 9)

# %% [raw]
# "Next to update Soon"
#
# Dropping Duplicates
#
# -drop dupliates()
# -keep='first'
